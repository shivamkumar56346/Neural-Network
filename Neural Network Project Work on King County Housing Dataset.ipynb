# %%
#Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
# Load our Dataset
df=pd.read_csv("C:/Users/Shivam/OneDrive/Documents/TensorFlow_FILES/DATA/kc_house_data.csv")
df.head(5)
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       21597 non-null int64
# view             21597 non-null int64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null int64
# yr_built         21597 non-null int64
# yr_renovated     21597 non-null int64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007547      0.234292      3.409825
# ...

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
df.shape
# Out:
# (21597, 21)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['price'])

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['bedrooms'])

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# waterfront    -0.002727  0.266398 -0.006834   0.063744     0.103854  0.021632
# view           0.011536  0.397370  0.080008   0.188386     0.284709  0.074900
# condition     -0.023803  0.036056  0.026496  -0.126479    -0.059445 -0.008830
# grade          0.008188  0.667951  0.356563   0.665838     0.762779  0.114731
# ...

# %%
df.corrwith(df['price']).sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# dtype: float64

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,6))
df.corr()['price'].sort_values().plot(kind='bar')

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr())

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df['sqft_living'],df['price'],data=df)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df['bedrooms'],df['price'],data=df)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df['bedrooms'],df['price'],data=df)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='lat',y='long',data=df)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='lat',y='long',data=df,hue='price',palette='rainbow')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='waterfront',y='price',data=df)

# %%
df=df.drop(['id'],axis=1)
df.head(5)
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
# 2   2/25/2015  180000.0         2       1.00          770     10000     1.0
# 3   12/9/2014  604000.0         4       3.00         1960      5000     1.0
# 4   2/18/2015  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
df.shape
# Out:
# (21597, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 20 columns):
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       21597 non-null int64
# view             21597 non-null int64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null int64
# yr_built         21597 non-null int64
# yr_renovated     21597 non-null int64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: float64(5), int64(14), object(1)
# memory usage: 3.3+ MB

# %%
df['date']=pd.to_datetime(df['date'])
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 20 columns):
# date             21597 non-null datetime64[ns]
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       21597 non-null int64
# view             21597 non-null int64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null int64
# yr_built         21597 non-null int64
# yr_renovated     21597 non-null int64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: datetime64[ns](1), float64(5), int64(14)
# ...

# %%
df['Year']=df['date'].apply(lambda date:date.year)
df['Month']=df['date'].apply(lambda date:date.month)
df['Day']=df['date'].apply(lambda date:date.day)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 23 columns):
# date             21597 non-null datetime64[ns]
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       21597 non-null int64
# view             21597 non-null int64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null int64
# yr_built         21597 non-null int64
# yr_renovated     21597 non-null int64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# Year             21597 non-null int64
# ...

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Month',y='price',data=df)

# %%
df.groupby('Year').mean()['price']
# Out:
# Year
# 2014    539350.911777
# 2015    542279.005878
# Name: price, dtype: float64

# %%
df.groupby('Year').mean()['price'].plot()

# %%
df.groupby('Year').mean()['price'].plot(kind='bar')

# %%
df.groupby('Month').mean()['price']
# Out:
# Month
# 1     525963.251534
# 2     508520.051323
# 3     544057.683200
# 4     562215.615074
# 5     550849.746893
# 6     557534.318182
# 7     544892.161013
# 8     536655.212481
# 9     529723.517787
# 10    539439.447228
# 11    522359.903478
# 12    524799.902041
# Name: price, dtype: float64

# %%
df.groupby('Month').mean()['price'].plot()

# %%
df.groupby('Month').mean()['price'].plot(kind='bar')

# %%
df=df.drop(['date'],axis=1)
df.head(5)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  yr_built  yr_renovated  zipcode      lat  \
# 0     0          3      7  ...      1955             0    98178  47.5112
# 1     0          3      7  ...      1951          1991    98125  47.7210
# 2     0          3      6  ...      1933             0    98028  47.7379
# 3     0          5      7  ...      1965             0    98136  47.5208
# 4     0          3      8  ...      1987             0    98074  47.6168
#
#       long  sqft_living15  sqft_lot15  Year  Month  Day
# ...

# %%
df=df.drop(['zipcode'],axis=1)
df.head(5)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#        lat     long  sqft_living15  sqft_lot15  Year  Month  Day
# ...

# %%
#Features
x=df.drop(['price'],axis=1)
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#        lat     long  sqft_living15  sqft_lot15  Year  Month  Day
# ...

# %%
# Converted Feature Dataframe to Numpy
x=x.values
print(x)
# Out:
# [[3.000e+00 1.000e+00 1.180e+03 ... 2.014e+03 1.000e+01 1.300e+01]
#  [3.000e+00 2.250e+00 2.570e+03 ... 2.014e+03 1.200e+01 9.000e+00]
#  [2.000e+00 1.000e+00 7.700e+02 ... 2.015e+03 2.000e+00 2.500e+01]
#  ...
#  [2.000e+00 7.500e-01 1.020e+03 ... 2.014e+03 6.000e+00 2.300e+01]
#  [3.000e+00 2.500e+00 1.600e+03 ... 2.015e+03 1.000e+00 1.600e+01]
#  [2.000e+00 7.500e-01 1.020e+03 ... 2.014e+03 1.000e+01 1.500e+01]]

# %%
# Label
y=df['price']
y.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
# Label DataFrame to Numpy
y=y.values
print(y)
# Out:
# [221900. 538000. 180000. ... 402101. 400000. 325000.]

# %%
# Split our dataset into train & test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=123)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (15117, 20) (6480, 20) (15117,) (6480,)

# %%
# Data Normalization with MinMaxScaler to prevent data leak.
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
# Importing Libraries for creating a neural network
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout,BatchNormalization

# %%
# Creating a neural network layers
model=Sequential()
model.add(Dense(20,input_shape=(20,),activation='relu'))
model.add(Dense(20,activation='relu'))
model.add(BatchNormalization())
model.add(Dense(20,activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1))

# %%
from keras import optimizers
adam=optimizers.Adam(lr=0.01)
model.compile(optimizer=adam,loss='mean_squared_error',metrics=['mse'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 20)                420
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                420
# _________________________________________________________________
# batch_normalization (BatchNo (None, 20)                80
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 20)                80
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 21
# ...
# Total params: 1,441
# Trainable params: 1,361
# Non-trainable params: 80
# ...

# %%
model.fit(x_train,y_train,validation_data=(x_test,y_test),batch_size=128,epochs=200,verbose=1)
# Out:
# Epoch 1/200
# 119/119 [==============================] - 4s 14ms/step - loss: 416201093120.0000 - mse: 416201093120.0000 - val_loss: 432252715008.0000 - val_mse: 432252715008.0000
# Epoch 2/200
# 119/119 [==============================] - 0s 4ms/step - loss: 424628314385.0667 - mse: 424628314385.0667 - val_loss: 432506273792.0000 - val_mse: 432506273792.0000
# Epoch 3/200
# 119/119 [==============================] - 0s 3ms/step - loss: 422698507468.8000 - mse: 422698507468.8000 - val_loss: 431833612288.0000 - val_mse: 431833612288.0000
# Epoch 4/200
# 119/119 [==============================] - 0s 3ms/step - loss: 432357079176.5333 - mse: 432357079176.5333 - val_loss: 429884309504.0000 - val_mse: 429884309504.0000
# Epoch 5/200
# 119/119 [==============================] - 0s 4ms/step - loss: 423749099793.0667 - mse: 423749099793.0667 - val_loss: 430226505728.0000 - val_mse: 430226505728.0000
# Epoch 6/200
# ...

# %%
model.history.history
# Out:
# {'loss': [424599322624.0,
#   424363425792.0,
#   423872397312.0,
#   423123681280.0,
#   422132940800.0,
#   420902699008.0,
#   419479814144.0,
#   417812840448.0,
#   415955845120.0,
#   413922263040.0,
#   411689451520.0,
#   409311608832.0,
#   406732996608.0,
#   404040810496.0,
#   401216962560.0,
#   398152269824.0,
#   395038851072.0,
#   391803863040.0,
#   388473847808.0,
#   384953778176.0,
#   381352902656.0,
#   377850920960.0,
#   373816033280.0,
#   369986994176.0,
#   366045528064.0,
#   362039967744.0,
#   357867454464.0,
#   353749991424.0,
#   349358096384.0,
#   344924160000.0,
#   340625063936.0,
#   336044654592.0,
#   331755028480.0,
#   327073366016.0,
#   322330296320.0,
#   317879779328.0,
#   313122095104.0,
#   308325023744.0,
#   303873294336.0,
#   298668818432.0,
#   293876367360.0,
#   288937345024.0,
#   283983773696.0,
#   279376953344.0,
#   274082775040.0,
#   269291798528.0,
#   264282210304.0,
#   259555540992.0,
#   254944313344.0,
# ...

# %%
loss_df=pd.DataFrame(model.history.history)
loss_df.head()
# Out:
#            loss           mse      val_loss       val_mse
# 0  4.245993e+11  4.245993e+11  4.322527e+11  4.322527e+11
# 1  4.243634e+11  4.243634e+11  4.325063e+11  4.325063e+11
# 2  4.238724e+11  4.238724e+11  4.318336e+11  4.318336e+11
# 3  4.231237e+11  4.231237e+11  4.298843e+11  4.298843e+11
# 4  4.221329e+11  4.221329e+11  4.302265e+11  4.302265e+11

# %%
plt.figure(figsize=(15,8))
loss_df.plot()

# %%
model.evaluate(x_test,y_test)
# Out:
# 203/203 [==============================] - 0s 2ms/step - loss: 21487935488.0000 - mse: 21487935488.0000
# [21487935488.0, 21487935488.0]

# %%
predictions=model.predict(x_test)
print(predictions)
# Out:
# [[ 253777.81]
#  [1240196.1 ]
#  [ 241310.8 ]
#  ...
#  [1539707.9 ]
#  [ 253228.53]
#  [1014491.5 ]]

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

# %%
print("MAE : ",mean_absolute_error(y_test,predictions))
print("MSE : ",mean_squared_error(y_test,predictions))
print("RMSE : ",np.sqrt(mean_squared_error(y_test,predictions)))
print("Explained Variance : ",explained_variance_score(y_test,predictions))
# Out:
# MAE :  82686.10471161266
# MSE :  21487928144.305187
# RMSE :  146587.6125199711
# Explained Variance :  0.8486486530457766

# %%
# Checking Mean Price of all the houses
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
# Taking a record for evaluating our model predictions for price of that particular house.
sample_df=df.drop('price',axis=1).iloc[0]
sample_df
# Out:
# bedrooms            3.0000
# bathrooms           1.0000
# sqft_living      1180.0000
# sqft_lot         5650.0000
# floors              1.0000
# waterfront          0.0000
# view                0.0000
# condition           3.0000
# grade               7.0000
# sqft_above       1180.0000
# sqft_basement       0.0000
# yr_built         1955.0000
# yr_renovated        0.0000
# lat                47.5112
# long             -122.2570
# sqft_living15    1340.0000
# sqft_lot15       5650.0000
# Year             2014.0000
# Month              10.0000
# Day                13.0000
# Name: 0, dtype: float64

# %%
sample_df.shape
# Out:
# (20,)

# %%
sample_df.values
# Out:
# array([ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#         1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#         7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#         0.00000e+00,  4.75112e+01, -1.22257e+02,  1.34000e+03,
#         5.65000e+03,  2.01400e+03,  1.00000e+01,  1.30000e+01])

# %%
single_house=sample_df.values.reshape(-1,20)

# %%
single_house=scaler.transform(single_house)
single_house
# Out:
# array([[0.0625    , 0.06666667, 0.06079027, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.4       , 0.08859358,
#         0.        , 0.47826087, 0.        , 0.56914119, 0.215     ,
#         0.16193426, 0.00573322, 0.        , 0.81818182, 0.4       ]])

# %%
model.predict(single_house)
# Out:
# array([[280018.47]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  Year  Month  Day
# 0  47.5112 -122.257           1340        5650  2014     10   13
#
# [1 rows x 21 columns]

# %%
# Conclusion 1: the actual price of a house is 221900.0 & our ann model predicts price of that house as 280018.47

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test,predictions)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')

# %%
# PART TWO 
# Creating a new ann model by building an another Neural Network.

# %%
def my_ann_model():
    model=Sequential()
    model.add(Dense(20,input_shape=(20,),activation='relu'))
    model.add(Dense(20,activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(20,activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(20,activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(1))
    adam=optimizers.Adam(lr=0.01)
    model.compile(optimizer=adam,loss='mean_squared_error',metrics=['mse'])
    return model

# %%
new_model=my_ann_model()

# %%
new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                420
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 20)                80
# _________________________________________________________________
# dense_6 (Dense)              (None, 20)                420
# _________________________________________________________________
# dropout (Dropout)            (None, 20)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 20)                420
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 20)                80
# ...

# %%
# Using Callbacks & Early Stopping for improving our model performance on test data.
from keras.callbacks import EarlyStopping
early_stop=EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=25)

# %%
new_model.fit(x_train,y_train,validation_data=(x_test,y_test),batch_size=128,epochs=400,verbose=1,callbacks=[early_stop])
# Out:
# Epoch 1/400
# 119/119 [==============================] - 2s 6ms/step - loss: 409267117806.9333 - mse: 409267117806.9333 - val_loss: 431997026304.0000 - val_mse: 431997026304.0000
# Epoch 2/400
# 119/119 [==============================] - 1s 4ms/step - loss: 426917116313.6000 - mse: 426917116313.6000 - val_loss: 431473623040.0000 - val_mse: 431473623040.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 4ms/step - loss: 426156233796.2667 - mse: 426156233796.2667 - val_loss: 430703607808.0000 - val_mse: 430703607808.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 4ms/step - loss: 412116110540.8000 - mse: 412116110540.8000 - val_loss: 429612630016.0000 - val_mse: 429612630016.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 4ms/step - loss: 408973304354.1334 - mse: 408973304354.1334 - val_loss: 429265453056.0000 - val_mse: 429265453056.0000
# Epoch 6/400
# ...

# %%
new_model.history.history
# Out:
# {'loss': [424601518080.0,
#   424381448192.0,
#   423920697344.0,
#   423213203456.0,
#   422271057920.0,
#   421097439232.0,
#   419730980864.0,
#   418152415232.0,
#   416401063936.0,
#   414431346688.0,
#   412295757824.0,
#   409984368640.0,
#   407568941056.0,
#   404908572672.0,
#   402201837568.0,
#   399340765184.0,
#   396301598720.0,
#   393240182784.0,
#   389810487296.0,
#   386616983552.0,
#   383086395392.0,
#   379575009280.0,
#   375982260224.0,
#   372126023680.0,
#   368327229440.0,
#   364465356800.0,
#   360397438976.0,
#   356397678592.0,
#   352235651072.0,
#   348028043264.0,
#   343918379008.0,
#   339558006784.0,
#   335148810240.0,
#   330614243328.0,
#   326136528896.0,
#   321620672512.0,
#   317100556288.0,
#   312391237632.0,
#   308220395520.0,
#   302975844352.0,
#   298456186880.0,
#   293470765056.0,
#   288913817600.0,
#   283937210368.0,
#   279036887040.0,
#   274569658368.0,
#   269620903936.0,
#   264790147072.0,
#   260038098944.0,
# ...

# %%
new_loss_df=pd.DataFrame(new_model.history.history)
new_loss_df.head()
# Out:
#            loss           mse      val_loss       val_mse
# 0  4.246015e+11  4.246015e+11  4.319970e+11  4.319970e+11
# 1  4.243814e+11  4.243814e+11  4.314736e+11  4.314736e+11
# 2  4.239207e+11  4.239207e+11  4.307036e+11  4.307036e+11
# 3  4.232132e+11  4.232132e+11  4.296126e+11  4.296126e+11
# 4  4.222711e+11  4.222711e+11  4.292655e+11  4.292655e+11

# %%
plt.figure(figsize=(15,8))
new_loss_df.plot()

# %%
new_model.evaluate(x_test,y_test)
# Out:
# 203/203 [==============================] - 0s 1ms/step - loss: 17259968512.0000 - mse: 17259968512.0000
# [17259968512.0, 17259968512.0]

# %%
prediction=new_model.predict(x_test)
prediction
# Out:
# array([[ 290841.97],
#        [1262985.2 ],
#        [ 270606.47],
#        ...,
#        [1441734.6 ],
#        [ 296087.4 ],
#        [ 918450.06]], dtype=float32)

# %%
print("MAE : ",mean_absolute_error(y_test,prediction))
print("MSE : ",mean_squared_error(y_test,prediction))
print("RMSE : ",np.sqrt(mean_squared_error(y_test,prediction)))
print("Explained Variance : ",explained_variance_score(y_test,prediction))
# Out:
# MAE :  74479.7602261767
# MSE :  17259972654.202618
# RMSE :  131377.21512576911
# Explained Variance :  0.8770873342967163

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test,prediction)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test,prediction)
plt.plot(y_test,y_test,'r')

# %%
# Taking one record for evaluating our model predictions.
sample=df.drop('price',axis=1).iloc[1]
sample
# Out:
# bedrooms            3.000
# bathrooms           2.250
# sqft_living      2570.000
# sqft_lot         7242.000
# floors              2.000
# waterfront          0.000
# view                0.000
# condition           3.000
# grade               7.000
# sqft_above       2170.000
# sqft_basement     400.000
# yr_built         1951.000
# yr_renovated     1991.000
# lat                47.721
# long             -122.319
# sqft_living15    1690.000
# sqft_lot15       7639.000
# Year             2014.000
# Month              12.000
# Day                 9.000
# Name: 1, dtype: float64

# %%
new_single_house=sample.values.reshape(-1,20)

# %%
new_single_house=scaler.transform(new_single_house)
new_single_house
# Out:
# array([[0.0625    , 0.23333333, 0.16641337, 0.00407187, 0.4       ,
#         0.        , 0.        , 0.5       , 0.4       , 0.19822813,
#         0.08298755, 0.44347826, 0.98808933, 0.90845868, 0.16333333,
#         0.22216486, 0.008018  , 0.        , 1.        , 0.26666667]])

# %%
new_model.predict(new_single_house)
# Out:
# array([[512779.22]], dtype=float32)

# %%
df['price'].iloc[1]
# Out:
# 538000.0

# %%
#Conclusion 2: 
#The actual price of a house is 538000.0 & our model predicts price of that house as 512779.22.

# %%
# Part Three
# Using Keras Regressor & GridSearchCV for HyperParameter Optimization & Tuning.

# %%
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasRegressor

# %%
third_model=KerasRegressor(build_fn=my_ann_model,verbose=1)

# %%
batch_size=[64,128]
epochs=[200,400]
param_grid=dict(batch_size=batch_size,epochs=epochs)
print(param_grid)
# Out:
# {'batch_size': [64, 128], 'epochs': [200, 400]}

# %%
grid=GridSearchCV(estimator=third_model,param_grid=param_grid,cv=2,scoring='r2',verbose=1,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 2 folds for each of 4 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:  4.7min finished
# Epoch 1/400
# 237/237 [==============================] - 2s 2ms/step - loss: 428917855756.9076 - mse: 428917855756.9076
# Epoch 2/400
# 237/237 [==============================] - 1s 3ms/step - loss: 416364184102.7227 - mse: 416364184102.7227
# Epoch 3/400
# 237/237 [==============================] - 1s 3ms/step - loss: 428260494292.9748 - mse: 428260494292.9748
# Epoch 4/400
# 237/237 [==============================] - 1s 2ms/step - loss: 422566249962.4874 - mse: 422566249962.4874
# Epoch 5/400
# 237/237 [==============================] - 1s 3ms/step - loss: 415823706232.4706 - mse: 415823706232.4706
# Epoch 6/400
# 237/237 [==============================] - 1s 2ms/step - loss: 404790445684.1681 - mse: 404790445684.1681
# Epoch 7/400
# ...

# %%
print("Best: %f using %s" % (grid.best_score_,grid.best_params_))
# Out:
# Best: 0.850554 using {'batch_size': 64, 'epochs': 400}

# %%
grid_predictions=grid.predict(x_test)
# Out:
# 102/102 [==============================] - 0s 1ms/step

# %%
print(grid_predictions)
# Out:
# [ 286329.72 1173422.    272739.38 ... 1735493.9   286062.75  984988.75]

# %%
print("MAE : ",mean_absolute_error(y_test,grid_predictions))
print("MSE : ",mean_squared_error(y_test,grid_predictions))
print("RMSE : ",np.sqrt(mean_squared_error(y_test,grid_predictions)))
print("Explained Variance : ",explained_variance_score(y_test,grid_predictions))
# Out:
# MAE :  75930.11097366898
# MSE :  16701187252.039337
# RMSE :  129233.07336761491
# Explained Variance :  0.8807737056007438

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test,grid_predictions)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test,grid_predictions)
plt.plot(y_test,y_test,'r')

# %%
# Taking a record for evaluating our model predictions.
new_sample=df.drop('price',axis=1).iloc[5]
new_sample
# Out:
# bedrooms              4.0000
# bathrooms             4.5000
# sqft_living        5420.0000
# sqft_lot         101930.0000
# floors                1.0000
# waterfront            0.0000
# view                  0.0000
# condition             3.0000
# grade                11.0000
# sqft_above         3890.0000
# sqft_basement      1530.0000
# yr_built           2001.0000
# yr_renovated          0.0000
# lat                  47.6561
# long               -122.0050
# sqft_living15      4760.0000
# sqft_lot15       101930.0000
# Year               2014.0000
# Month                 5.0000
# Day                  12.0000
# Name: 5, dtype: float64

# %%
new_house=new_sample.values.reshape(-1,20)

# %%
new_house=scaler.transform(new_house)
new_house
# Out:
# array([[0.09375   , 0.53333333, 0.38297872, 0.06142937, 0.        ,
#         0.        , 0.        , 0.5       , 0.8       , 0.38870432,
#         0.31742739, 0.87826087, 0.        , 0.80349345, 0.425     ,
#         0.75047324, 0.11633111, 0.        , 0.36363636, 0.36666667]])

# %%
grid.predict(new_house)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# array(1277056.8, dtype=float32)

# %%
df['price'].iloc[5]
# Out:
# 1230000.0

# %%
#Conclusion 3:
#The actual price of a house is 1230000.0 & our ann model predicts price of that house as 1277056.8
